# %% [markdown]
# <img src='https://encrypted-tbn0.gstatic.com/images?q=tbn%3AANd9GcQ-VfNtOyJbsaxu43Kztf_cv1mgBG6ZIQZEVw&usqp=CAU'>
#
# # Procesamiento de Lenguage Natural
#
# ## Taller #8: Modelado de temas
# `Fecha de entrega: 🎃Octubre 31, 2020. (Antes del inicio de la próxima clase).`
#
# `Modo de entrega: Subir link de GitHub al aula virtual.`

# %%
import re
import pandas as pd 
from pprint import pprint

from nltk.corpus import stopwords
stopwords = stopwords.words('spanish')

import pyLDAvis.gensim
from gensim.models import LdaModel
from gensim.corpora import Dictionary

import warnings
warnings.filterwarnings("ignore", category=DeprecationWarning)
# Out:
# C:\Users\jlo46\Anaconda3\lib\site-packages\scipy\sparse\sparsetools.py:21: DeprecationWarning: `scipy.sparse.sparsetools` is deprecated!
# scipy.sparse.sparsetools is a private module for scipy.sparse, and should not be used.
#   _deprecated()

# %%
# Cargar datos
path = 'C:/Users/jlo46/OneDrive/Documentos/ESPECIALIZACION/SEMESTRE 2/Fundamentos NLP/TALLER 7/reviews_vidjew_es.csv'
data = pd.read_csv(path)
data.head()
# Out:
#     review_id          product_id          reviewer_id  stars  \
# 0  es_0825565  product_es_0370490  reviewer_es_0174781      3
# 1  es_0227934  product_es_0354224  reviewer_es_0411613      3
# 2  es_0468601  product_es_0665460  reviewer_es_0348315      1
# 3  es_0814494  product_es_0692692  reviewer_es_0951508      5
# 4  es_0206329  product_es_0728826  reviewer_es_0493255      4
#
#                                          review_body            review_title  \
# 0         Buen. Buena calidad, y buena presentación.                Contenta
# 1  Un producto a perfecto, para salir de casa con...            Versatilidad
# 2  No funciona con Nintendo Switch. No hay forma ...      Decepción absoluta
# 3  Recomendado, los utilizo para pc y no me dan n...  Auriculares Pecham ps4
# 4  El cable funciona bien podria ser un poco mas ...                Perfecto
#
#   language product_category
# 0       es          jewelry
# 1       es      video_games
# 2       es      video_games
# 3       es      video_games
# 4       es      video_games

# %% [markdown]
# ###  `[12 pts]` Punto 1: Hacer pre-procesamiento del texto

# %%
def pre_procesado(texto):
    texto = texto.lower()
    texto = re.sub(r"[\W\d_]+", " ", texto)
    texto = [palabra for palabra in texto.split() if palabra not in stopwords]
    return texto
data['pp'] = data['review_body'].apply(lambda texto: pre_procesado(texto))

data.head()
# Out:
#     review_id          product_id          reviewer_id  stars  \
# 0  es_0825565  product_es_0370490  reviewer_es_0174781      3
# 1  es_0227934  product_es_0354224  reviewer_es_0411613      3
# 2  es_0468601  product_es_0665460  reviewer_es_0348315      1
# 3  es_0814494  product_es_0692692  reviewer_es_0951508      5
# 4  es_0206329  product_es_0728826  reviewer_es_0493255      4
#
#                                          review_body            review_title  \
# 0         Buen. Buena calidad, y buena presentación.                Contenta
# 1  Un producto a perfecto, para salir de casa con...            Versatilidad
# 2  No funciona con Nintendo Switch. No hay forma ...      Decepción absoluta
# 3  Recomendado, los utilizo para pc y no me dan n...  Auriculares Pecham ps4
# 4  El cable funciona bien podria ser un poco mas ...                Perfecto
#
#   language product_category                                                 pp
# 0       es          jewelry        [buen, buena, calidad, buena, presentación]
# 1       es      video_games  [producto, perfecto, salir, casa, nintendo, sw...
# 2       es      video_games  [funciona, nintendo, switch, forma, emparejarl...
# 3       es      video_games  [recomendado, utilizo, pc, dan, ningún, proble...
# 4       es      video_games  [cable, funciona, bien, podria, ser, mas, larg...

# %% [markdown]
# ###  `[13 pts]` Punto 2: Modelo de LDA

# %%
# Crear una representación de los documentos en forma de diccionario
dictionary = Dictionary(data['pp'].values)

# Filtrar palabras muy frecuentes o infrecuentes
dictionary.filter_extremes(no_below=5, no_above=0.5)
corpus = [dictionary.doc2bow(text) for text in data['pp'].values]

#Train the topic model
modelo = LdaModel(corpus=corpus, id2word=dictionary, num_topics=2, passes=50)

# %% [markdown]
# ###  `[25 pts]` Punto 3: Visualización de LDA

# %%
lda_display = pyLDAvis.gensim.prepare(modelo, corpus, dictionary, sort_topics=True)
pyLDAvis.display(lda_display)
# Out:
# C:\Users\jlo46\Anaconda3\lib\site-packages\pyLDAvis\_prepare.py:257: FutureWarning: Sorting because non-concatenation axis is not aligned. A future version
# of pandas will change to not sort by default.
#
# To accept the future behavior, pass 'sort=False'.
#
# To retain the current behavior and silence the warning, pass 'sort=True'.
#
#   return pd.concat([default_term_info] + list(topic_dfs))
# <link rel="stylesheet" type="text/css" href="https://cdn.rawgit.com/bmabey/pyLDAvis/files/ldavis.v1.0.0.css">
#
#
# <div id="ldavis_el515624524561730005892921418"></div>
# <script type="text/javascript">
#
# var ldavis_el515624524561730005892921418_data = {"mdsDat": {"x": [0.14135056734085083, -0.14135056734085083], "y": [0.0, 0.0], "topics": [1, 2], "cluster": [1, 1], "Freq": [53.9996452331543, 46.0003547668457]}, "tinfo": {"Category": ["Default", "Default", "Default", "Default", "Default", "Default", "Default", "Default", "Default", "Default", "Default", "Default", "Default", "Default", "Default", "Default", "Default", "Default", "Default", "Default", "Default", "Default", "Default", "Default", "Default", "Default", "Default", "Default", "Default", "Default", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2"], "Freq": [117.0, 112.0, 63.0, 52.0, 50.0, 48.0, 39.0, 52.0, 42.0, 37.0, 35.0, 34.0, 34.0, 50.0, 32.0, 34.0, 29.0, 28.0, 29.0, 34.0, 26.0, 33.0, 28.0, 39.0, 25.0, 24.0, 31.0, 24.0, 31.0, 29.0, 116.01202392578125, 33.34091567993164, 51.83953094482422, 111.02714538574219, 34.22670364379883, 28.640634536743164, 31.28861427307129, 23.900510787963867, 22.972829818725586, 22.049644470214844, 22.011394500732422, 30.25567054748535, 20.166616439819336, 20.159271240234375, 21.06938934326172, 16.440631866455078, 49.243499755859375, 17.320606231689453, 15.481511116027832, 14.552006721496582, 14.536020278930664, 18.160037994384766, 13.596729278564453, 16.315052032470703, 13.5922212600708, 18.927391052246094, 11.709339141845703, 11.704977035522461, 17.996986389160156, 12.595131874084473, 23.28661346435547, 15.25727367401123, 33.30839157104492, 42.46187210083008, 20.39803123474121, 19.463621139526367, 41.13522720336914, 30.844079971313477, 24.698326110839844, 33.97394943237305, 80.95893096923828, 71.48755645751953, 42.755149841308594, 42.09330368041992, 82.79827880859375, 38.11578369140625, 27.60209083557129, 50.990848541259766, 31.72105598449707, 26.116777420043945, 27.535367965698242, 24.156818389892578, 23.517688751220703, 63.034358978271484, 38.71812438964844, 34.06854248046875, 32.192230224609375, 34.025516510009766, 36.77194595336914, 34.91978073120117, 51.35555648803711, 24.74055290222168, 25.65509033203125, 49.3621711730957, 20.98239517211914, 28.23764991760254, 23.664199829101562, 20.9127254486084, 29.024295806884766, 23.5673828125, 47.12312316894531, 19.008464813232422, 28.933853149414062, 14.458003997802734, 14.422788619995117, 14.416715621948242, 13.500985145568848, 20.673168182373047, 27.8051815032959, 11.650911331176758, 17.920236587524414, 41.21665954589844, 16.107830047607422, 32.6512451171875, 21.040035247802734, 34.973575592041016, 93.22242736816406, 19.9276123046875, 102.72222900390625, 42.68714904785156, 35.39134979248047, 24.56428337097168, 29.49329376220703, 31.500347137451172, 35.39946365356445, 33.60047912597656], "Term": ["juego", "si", "bonito", "foto", "llegado", "d\u00eda", "bonitos", "mando", "lleg\u00f3", "pulsera", "queda", "plata", "tama\u00f1o", "puede", "cadena", "esperaba", "tal", "pendientes", "peque\u00f1o", "funciona", "bonita", "jugar", "demasiado", "dos", "colgante", "cierre", "original", "grandes", "pena", "ps", "juego", "jugar", "mando", "si", "funciona", "ps", "original", "menos", "juegos", "cable", "va",  ...
